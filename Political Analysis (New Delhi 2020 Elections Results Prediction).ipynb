# %% [markdown]
# ## Analysis of Loksabha Results
#
# **Here, for analysis we are taking the dataset of past loksabha election results. As the Loksabha elections were held in the month of 2009 and 2014, here we are going to take the results in the form of dataset of those two election results**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Taking the dataset of Loksabha 2009 Election Results
df = pd.read_csv("2009.csv")

# %%
df
# Out:
#     Serial No. of Polling Station  Ajay\nMakan  Trilok chand Sharma  \
# 0                               1            1                    2
# 1                               2          330                    2
# 2                               3          205                    6
# 3                               4          279                  102
# 4                               5          108                    3
# 5                               6          198                    3
# 6                               7          234                   12
# 7                               8          255                    6
# 8                               9          297                   92
# 9                              10          249                    5
# 10                             11          161                  102
# 11                             12          418                   51
# 12                             13          142                    2
# ...

# %%
df.shape
# Out:
# (165, 46)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 46 columns):
# Serial No. of Polling Station                                         165 non-null object
# Ajay
# Makan                                                            165 non-null int64
# Trilok chand Sharma                                                   165 non-null int64
# Vijay Goel                                                            165 non-null int64
# Aamer Ahmed Madni                                                     165 non-null int64
# Jitendar Kumar Gupta                                                  165 non-null int64
# Naresh Chander Pal                                                    165 non-null int64
# Nisha
# Bano                                                            165 non-null int64
# Maharaj
# Kumar                                                         165 non-null int64
# Murtaza
# ...

# %%
df.columns
# Out:
# Index(['Serial No. of Polling Station', 'Ajay\nMakan', 'Trilok chand Sharma',
#        'Vijay Goel', 'Aamer Ahmed Madni', 'Jitendar Kumar Gupta',
#        'Naresh Chander Pal', 'Nisha\nBano', 'Maharaj\nKumar', 'Murtaza\nPhool',
#        'Raj Kumar\nNayyar', 'Rajesh Kumar Sabharwal', 'Major Sangeeta Tomar',
#        'Sanjeev Kumar Mishra', 'Sudhir\nKumar', 'Unnamed: 15',
#        'Sudhir\nGandotra', 'Sunita Chaudhar y', 'Harender', 'Harsh\nMalhotra',
#        'Ajay Prakash Harit', 'Anil Kumar Gautam', 'Ashutosh\nKumar',
#        'Kapil Mitra', 'Karan\nKumar', 'Krishan Kumar Tyagi', 'Ghanshya m Dass',
#        'Jagat Singh Chauhan', 'Dinesh\nKumar', 'Prem Narayan Khandelw al',
#        'BHAGWA N DAS', 'B.B. Malhotra', 'Mantu', 'Ramesh\nBhagwat',
#        'Lachhman\nDass', 'Lukman\nKhan', 'Ved\nPrakash',
#        'Shiban Krishan Razdan', 'Shiv Kumar Shah', 'Sapna\nRani Behl',
#        'Surender Singh Dabas', 'Harkrisha n Das Nijhawan',
#        'Total of valid votes',
# ...

# %%
df.describe()
# Out:
#        Ajay\nMakan  Trilok chand Sharma  Vijay Goel  Aamer Ahmed Madni  \
# count   165.000000           165.000000  165.000000         165.000000
# mean    305.133333            14.109091  195.587879           1.266667
# std      98.710561            25.060906   73.090321           1.269402
# min       1.000000             0.000000    3.000000           0.000000
# 25%     243.000000             3.000000  145.000000           0.000000
# 50%     311.000000             5.000000  201.000000           1.000000
# 75%     377.000000            11.000000  245.000000           2.000000
# max     638.000000           135.000000  412.000000           7.000000
#
#        Jitendar Kumar Gupta  Naresh Chander Pal  Nisha\nBano  Maharaj\nKumar  \
# count            165.000000          165.000000   165.000000      165.000000
# mean               0.278788            0.218182     0.187879        0.163636
# std                0.677044            0.615578     0.649464        0.700965
# ...

# %%
df = pd.read_csv("2014.csv")

# %%
df
# Out:
#      Serial No. of Polling Station  AJAY MAKAN  ASHISH KHETAN  \
# 0                                1         180            226
# 1                                2         120            182
# 2                                3          95            139
# 3                                4          90            137
# 4                                5          97            154
# 5                                6         204            186
# 6                                7          78            133
# 7                                8         115            142
# 8                                9         250            246
# 9                               10         158            218
# 10                              11          53             56
# 11                              12          77            124
# 12                              13         111            176
# 13                              14          59            131
# ...

# %%
df.shape
# Out:
# (156, 34)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 34 columns):
# Serial No. of Polling Station         156 non-null int64
# AJAY MAKAN                            156 non-null int64
# ASHISH KHETAN                         156 non-null int64
# MEENAKASHI LEKHI                      156 non-null int64
# SOLOMON GEORGE                        156 non-null int64
# DEVI SINGH                            156 non-null int64
# DHEERAJ PURI                          156 non-null int64
# NAVEEN CHANDRA                        156 non-null int64
# PRADEEP VARMA                         156 non-null int64
# BISWAJIT RANJIT CHATTERJEE            156 non-null int64
# MEENA SINGLA                          156 non-null int64
# RAMANUJ PATEL                         156 non-null int64
# LAKSHMI NARAYAN                       156 non-null int64
# SWADESH OHRI                          156 non-null int64
# SUJEET JHA                            156 non-null int64
# ...

# %%
df.columns #No. of columns in the dataset
# Out:
# Index(['Serial No. of Polling Station', 'AJAY MAKAN', 'ASHISH KHETAN',
#        'MEENAKASHI LEKHI', 'SOLOMON GEORGE', 'DEVI SINGH', 'DHEERAJ PURI',
#        'NAVEEN CHANDRA', 'PRADEEP VARMA', 'BISWAJIT RANJIT CHATTERJEE',
#        'MEENA SINGLA', 'RAMANUJ PATEL', 'LAKSHMI NARAYAN', 'SWADESH OHRI',
#        'SUJEET JHA', 'SUNITA CHAUDHARY', 'ANJUMAN AGNIHOTRI', 'GHANSHYAM DASS',
#        'DAL CHAND', 'NARENDRA SINGH RAWAT', 'NIKHIL SABLANIA',
#        'PADMAJA KANDUKURI', 'RATHEESH', 'RAVI KUMAR GUPTA', 'RUBINA KHAN',
#        'LUKMAN KHAN', 'VISHAL KHOSLA', 'VED PRAKASH', 'K P SANKARAN MENON',
#        'HARKRISHAN DAS NIJHAWAN', 'Total of valid votes',
#        'No. of rejected votes (Test Votes)', 'Votes for 'NOTA' option',
#        'Total no. of tendered votes'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Serial No. of Polling Station  AJAY MAKAN  ASHISH KHETAN  \
# count                     156.000000  156.000000     156.000000
# mean                       78.500000  110.974359     184.801282
# std                        45.177428   39.085341      79.216113
# min                         1.000000   28.000000      56.000000
# 25%                        39.750000   83.000000     131.000000
# 50%                        78.500000  106.500000     170.500000
# 75%                       117.250000  130.000000     224.500000
# max                       156.000000  271.000000     485.000000
#
#        MEENAKASHI LEKHI  SOLOMON GEORGE  DEVI SINGH  DHEERAJ PURI  \
# count        156.000000      156.000000  156.000000    156.000000
# mean         353.846154        3.083333    0.096154      0.108974
# std          117.449297        4.253209    0.336564      0.351471
# min           72.000000        0.000000    0.000000      0.000000
# ...

# %% [markdown]
# ### Comparing Both 2009 & 2014 Election Results

# %% [markdown]
# #### Observations from 2009 election results
# * As per the observations, the number of valid votes of Loksabha results 2009, there are almost 87001 valid votes casted and 0 votes were rejected. This record comes from all the polling stations together of the constituency **Greater Kailash**
# * Amongst all the members, the highest voted member from the costituency is _Mr. Ajay Makan_ who got 50346 votes in total from all polling stations and the second highest member is Mr. Vijay Goel who got over 32269 votes.
#
# #### Observations from 2014 election results
# * In case of 2014 elections results, there are almost 104339 which is total no. of valid votes and again 0 rejected votes.
# * Amongst all the members, the highest voted member from **Greater Kailash** constituency is _Ms. Meenakshi Lekhi_ as she voted with the highest number of votes of about 55200 which is quite interesting as in the year 2009, the highest votes were upto 5036 compared to which in 2014 the votes are preety hiked up in high ammount.
# * On the other hand, _Mr. Ajay Makan_ who was leading with the highest voted member of about 5036 here he is lagging behind by 37888 votes when comparing with _Ms. Meenakshi Lekhi_.
# * Coming back to observations,then the second highest voted member is _Mr. Ashish Khetan_ who got about 28829 votes in total from all polling stations in the constituency.

# %% [markdown]
# ### 2009 Vs. 2014 Election Results

# %% [markdown]
# * On the scale of differentiation, the major differnce on behalf of Minimum and Maximum votes of members as mentioned, is the number of members who is standing in the elections of **Greater Kailash** constituency.
#
# * In the year 2009,the number of members standing in the elecion in given constituency was 29 and in the year 2014 the number of members standing was increased to 40 which is about 11 members more than 2009 elections

# %% [markdown]
# ## Analysis of Vidhansabha 2015 Results
#
# **Let's analyse the data of the Vidhansabha election results of the year 2015. Analysis of this result is very importsnt in all aspects the very first aspect is this is the freshly available past data on which analysis is important for better prediction and another is our prediction for the year 2020 would be completely or say more likely to be dependent on this data as the lastest past performance evaluation will give us some idea and intution about results of election which would be conducted in the year 2020**

# %%
df = pd.read_csv ("2015.csv")

# %%
df
# Out:
#      Serial No. of Polling Station  ADITYA  RAKESH KUMAR GULLAIYA  \
# 0                                1       3                    435
# 1                                2       3                    221
# 2                                3       0                    361
# 3                                4       2                    255
# 4                                5       0                    345
# 5                                6       8                    222
# 6                                7       0                    146
# 7                                8       2                    154
# 8                                9       3                    229
# 9                               10       0                    209
# 10                              11       2                    207
# 11                              12       0                    363
# 12                              13       0                    619
# ...

# %%
df.shape
# Out:
# (156, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 13 columns):
# Serial No. of Polling Station    156 non-null int64
# ADITYA                           156 non-null int64
# RAKESH KUMAR GULLAIYA            156 non-null int64
# ROHIT TYAGI                      156 non-null int64
# SHARMISTHA MUKHARJEE             156 non-null int64
# SAURABH BHARADWAJ                156 non-null int64
# ASHOK KUMAR                      156 non-null int64
# ASHOK KUMAR SHARMA               156 non-null int64
# SANJAY KHATRI                    156 non-null int64
# Total of Valid Votes             156 non-null int64
# No. of rejected votes            156 non-null int64
# NOTA                             156 non-null int64
# No. of Tendered votes            156 non-null int64
# dtypes: int64(13)
# memory usage: 15.9 KB

# %%
df.describe()
# Out:
#        Serial No. of Polling Station      ADITYA  RAKESH KUMAR GULLAIYA  \
# count                     156.000000  156.000000             156.000000
# mean                       78.500000    1.512821             275.012821
# std                        45.177428    2.233144             111.191784
# min                         1.000000    0.000000              46.000000
# 25%                        39.750000    0.000000             198.250000
# 50%                        78.500000    1.000000             268.000000
# 75%                       117.250000    2.000000             349.750000
# max                       156.000000   14.000000             619.000000
#
#        ROHIT TYAGI  SHARMISTHA MUKHARJEE  SAURABH BHARADWAJ  ASHOK KUMAR  \
# count   156.000000            156.000000         156.000000   156.000000
# mean      0.737179             38.923077         368.141026     1.525641
# std       0.843282             16.496544         160.646534     1.496011
# ...

# %% [markdown]
# #### Observations

# %% [markdown]
# * Looking at the 2015 election results, at first glance the data seems to be very descent and pleasant as the data is lengthy but the breadth of the data is not much vast
# * It means that the number of members standing for the election are far too less than the previous years Vidhansabha and Loksabha election.
# * In total about 8 members were standing in this election which is comparatively very less than all previous year elections.

# %% [markdown]
# #### Visualizations by histogram plot

# %%
df.hist(figsize=(30,30), xrot=-45)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10f334198>,
# ...
#       dtype=object)

# %%
#Dropping Unnecessary Feature
df = df.drop("Serial No. of Polling Station", axis=1)

# %%
df.hist(figsize=(30,30), xrot=-45)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a0b1c17b8>,
# ...
#       dtype=object)

# %% [markdown]
# #### Observations

# %% [markdown]
# * Observing the visualizations, then amongst all the members *Mr.SAURABH BHARADWAJ* has the highest votes of about 57589 as maximum polling stations have highest amount of votes which goes to *Mr. BHARADWAJ*
# * After *Mr. SAURABH BHARADWAJ*, *Mr. RAKESH KUMAR GULLAIYA* is the second highest voted member having highest votes of about 43006
# * In the same way *Ms. SHARMISTHA MUKHARJEE* is the third highest

# %%
df = pd.read_csv("2015.csv")

# %%
df = df.drop("Serial No. of Polling Station", axis=1)

# %%
df
# Out:
#      ADITYA  RAKESH KUMAR GULLAIYA  ROHIT TYAGI  SHARMISTHA MUKHARJEE  \
# 0         3                    435            0                    51
# 1         3                    221            1                    41
# 2         0                    361            1                    43
# 3         2                    255            1                    29
# 4         0                    345            1                    51
# 5         8                    222            1                    55
# 6         0                    146            0                    20
# 7         2                    154            1                    22
# 8         3                    229            0                    53
# 9         0                    209            1                    72
# 10        2                    207            1                    22
# 11        0                    363            1                    29
# ...

# %%
X = df.iloc[:,0:7]

# %%
X
# Out:
#      ADITYA  RAKESH KUMAR GULLAIYA  ROHIT TYAGI  SHARMISTHA MUKHARJEE  \
# 0         3                    435            0                    51
# 1         3                    221            1                    41
# 2         0                    361            1                    43
# 3         2                    255            1                    29
# 4         0                    345            1                    51
# 5         8                    222            1                    55
# 6         0                    146            0                    20
# 7         2                    154            1                    22
# 8         3                    229            0                    53
# 9         0                    209            1                    72
# 10        2                    207            1                    22
# 11        0                    363            1                    29
# ...

# %%
y = df.iloc[:,8:12]

# %%
y
# Out:
#      Total of Valid Votes  No. of rejected votes  NOTA  No. of Tendered votes
# 0                     983                      0     8                      0
# 1                     761                      0     4                      0
# 2                     822                      0     6                      0
# 3                     698                      0     1                      0
# 4                     831                      0     1                      0
# 5                     802                      0     4                      0
# 6                     441                      0     1                      0
# 7                     534                      0     3                      0
# 8                     935                      0     1                      0
# 9                     764                      0     4                      0
# 10                    352                      0     2                      0
# ...

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size = 0.2, random_state = 0)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
print(y_pred)
# Out:
# [[ 5.95993802e+02  0.00000000e+00  3.30362254e+00 -7.46052310e-03]
#  [ 5.20223468e+02  0.00000000e+00  1.31382934e+00  9.36285624e-03]
#  [ 6.61126214e+02  0.00000000e+00  2.97396263e+00  8.26637759e-03]
#  [ 6.58995024e+02  0.00000000e+00  3.09532760e+00  1.39115116e-02]
#  [ 6.46065943e+02  0.00000000e+00  3.40322945e+00 -6.15402590e-03]
#  [ 5.33611641e+02  0.00000000e+00  1.10070753e+00  1.27243707e-02]
#  [ 8.30442550e+02  0.00000000e+00  4.47170621e+00  1.53958610e-02]
#  [ 5.34064366e+02  0.00000000e+00  3.46772387e+00 -1.95415804e-02]
#  [ 6.32853667e+02  0.00000000e+00  2.35785761e+00  2.72676901e-02]
#  [ 7.98481034e+02  0.00000000e+00  2.97599820e+00  2.00965064e-02]
#  [ 9.76578631e+02  0.00000000e+00  3.40599901e+00  2.64202918e-02]
#  [ 6.81285080e+02  0.00000000e+00  3.21033503e+00 -7.87942856e-03]
#  [ 7.17970246e+02  0.00000000e+00  3.58873344e+00  1.84756436e-02]
#  [ 4.78773663e+02  0.00000000e+00  2.60548265e+00  3.32432983e-03]
# ...

# %%
df = pd.DataFrame(y_pred)

# %% [markdown]
# #### Predicted Results

# %%
df
# Out:
#               0    1         2         3
# 0    595.993802  0.0  3.303623 -0.007461
# 1    520.223468  0.0  1.313829  0.009363
# 2    661.126214  0.0  2.973963  0.008266
# 3    658.995024  0.0  3.095328  0.013912
# 4    646.065943  0.0  3.403229 -0.006154
# 5    533.611641  0.0  1.100708  0.012724
# 6    830.442550  0.0  4.471706  0.015396
# 7    534.064366  0.0  3.467724 -0.019542
# 8    632.853667  0.0  2.357858  0.027268
# 9    798.481034  0.0  2.975998  0.020097
# 10   976.578631  0.0  3.405999  0.026420
# 11   681.285080  0.0  3.210335 -0.007879
# 12   717.970246  0.0  3.588733  0.018476
# 13   478.773663  0.0  2.605483  0.003324
# 14   595.019034  0.0  3.376696  0.003476
# 15   507.883458  0.0  2.291590  0.011400
# 16   963.451151  0.0  4.627829  0.032013
# 17   748.161632  0.0  4.192347  0.001437
# 18   408.821146  0.0  2.543407 -0.014729
# 19   829.938986  0.0  3.847411  0.044227
# 20   483.804242  0.0  2.659243 -0.022376
# 21   936.991794  0.0  2.790766  0.039266
# ...

# %%
plt.plot(df)
plt.show()
